# %% [markdown]
# 第一步：地點選擇原因視覺化

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 載入資料
data = pd.read_csv('/Users/yulin/Desktop/人流/人工智慧/city_challengedata.csv')

# %%
# 移除缺失資料點
data = data[(data['x'] != 999) & (data['y'] != 999)]

# 確認資料結構
data.info()

# 統計每個網格 (x, y) 出現的資料筆數
grid_counts = data.groupby(['x', 'y']).size().reset_index(name='count')

# 找出資料筆數最多的前三個網格
top_grids = grid_counts.nlargest(3, 'count')

# 顯示結果
print(top_grids)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23913082 entries, 0 to 23913081
# Data columns (total 5 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   uid     int64
#  1   d       int64
#  2   t       int64
#  3   x       int64
#  4   y       int64
# dtypes: int64(5)
# memory usage: 1.1 GB
#         x   y   count
# 11877  80  95  122068
# 11874  80  92  118145
# 11875  80  93  113517

# %%
# 增加網格範圍：改成預測這四個點的人數加總
# 80 92, 80 93, 81 92, 81 93
filtered_data = data[
    ((data['x'] == 80) & (data['y'] == 92)) |
    ((data['x'] == 80) & (data['y'] == 93)) |
    ((data['x'] == 81) & (data['y'] == 92)) |
    ((data['x'] == 81) & (data['y'] == 93))
]

# 將時間 t 轉換為小時（t=0-47 每半小時記錄一次，所以乘以 0.5）
filtered_data['hours'] = filtered_data['d'] * 24 + (filtered_data['t'] // 2)
# 根據小時排序資料
filtered_data = filtered_data.sort_values(by='hours')

# 統計每小時的人數
hourly_counts = filtered_data.groupby('hours').size().reset_index(name='count')
# 保存結果
hourly_counts.to_csv('x=80y=95.csv', index=False)

# 繪製時間與人流量的關係圖
plt.figure(figsize=(15, 6))
plt.plot(hourly_counts['hours'], hourly_counts['count'], marker='o', linestyle='-')
plt.title('Hourly Traffic Volume for Grid (80 92) (80 93) (81 92) (81 93)')
plt.xlabel('Hours (from Day 0 Hour 0 to Day 74 Hour 23)')
plt.ylabel('Number of Users')
plt.grid(True)
plt.show()
# Out:
# /var/folders/n2/fm6sdglj7ys6t3b8yg12ybwr0000gn/T/ipykernel_83938/604015287.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['hours'] = filtered_data['d'] * 24 + (filtered_data['t'] // 2)

# %% [markdown]
# 第二步：預測人流量

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# 讀取資料
data = pd.read_csv('city_challengedata.csv')  # 確保資料檔案正確
# 增加網格範圍：改成預測這四個點的人數加總
# 80 92, 80 93, 81 92, 81 93
filtered_data = data[
    ((data['x'] == 80) & (data['y'] == 92)) |
    ((data['x'] == 80) & (data['y'] == 93)) |
    ((data['x'] == 81) & (data['y'] == 92)) |
    ((data['x'] == 81) & (data['y'] == 93))
]

# 計算星期與時間 (0:星期一 ~ 6:星期日)
filtered_data['weekday'] = filtered_data['d'] % 7  # 取模7得到星期
filtered_data['hour_of_day'] = filtered_data['t'] // 2  # 小時

# 根據星期與時間分組，統計每組人數
grouped_data = filtered_data.groupby(['d', 'weekday', 'hour_of_day']).size().reset_index(name='count')

# 切割資料集：前 60 天為訓練集，後 20 天為驗證集
train_data = grouped_data[grouped_data['d'] <= 59]  # 前 60 天的資料
val_data = grouped_data[grouped_data['d'] > 59]     # 後 20 天的資料

# 整理輸入特徵與標籤
X_train = train_data[['weekday', 'hour_of_day']].values  # 特徵：星期與小時
y_train = train_data['count'].values.reshape(-1, 1)      # 標籤：人數

X_val = val_data[['weekday', 'hour_of_day']].values      # 驗證集特徵
y_val = val_data['count'].values.reshape(-1, 1)         # 驗證集標籤

# 標準化資料
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_x.fit_transform(X_train)
y_train_scaled = scaler_y.fit_transform(y_train)

X_val_scaled = scaler_x.transform(X_val)  # 使用相同的縮放器進行驗證集標準化
y_val_scaled = scaler_y.transform(y_val)

# 建立 DNN 模型
model = Sequential()
model.add(Dense(64, input_dim=2, activation='relu'))  # 2 維特徵輸入
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))  # 預測單一輸出

# 編譯模型
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# 訓練模型
history = model.fit(X_train_scaled, y_train_scaled, 
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(X_val_scaled, y_val_scaled))

# 預測驗證集
y_pred_scaled = model.predict(X_val_scaled)
y_pred_rescaled = scaler_y.inverse_transform(y_pred_scaled)
y_val_rescaled = scaler_y.inverse_transform(y_val_scaled)

# 繪製預測與實際值比較圖
plt.figure(figsize=(15, 6))
plt.plot(y_val_rescaled, label='Actual', marker='o')
plt.plot(y_pred_rescaled, label='Predicted', marker='x')
plt.title('the highest variance of 4 spots-DNN Prediction vs Actual Traffic Volume (Grouped by Weekday and Hour)')
plt.xlabel('Test Samples')
plt.ylabel('Number of Users')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /var/folders/n2/fm6sdglj7ys6t3b8yg12ybwr0000gn/T/ipykernel_83938/1805818246.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['weekday'] = filtered_data['d'] % 7  # 取模7得到星期
# /var/folders/n2/fm6sdglj7ys6t3b8yg12ybwr0000gn/T/ipykernel_83938/1805818246.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['hour_of_day'] = filtered_data['t'] // 2  # 小時
# Epoch 1/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0506 - mae: 0.1817 - val_loss: 0.0312 - val_mae: 0.1426
# Epoch 2/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0398 - mae: 0.1613 - val_loss: 0.0247 - val_mae: 0.1313
# Epoch 3/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345 - mae: 0.1498 - val_loss: 0.0195 - val_mae: 0.1135
# Epoch 4/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0260 - mae: 0.1284 - val_loss: 0.0128 - val_mae: 0.0898
# Epoch 5/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0206 - mae: 0.1112 - val_loss: 0.0082 - val_mae: 0.0678
# Epoch 6/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0173 - mae: 0.0996 - val_loss: 0.0082 - val_mae: 0.0670
# Epoch 7/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0149 - mae: 0.0888 - val_loss: 0.0071 - val_mae: 0.0634
# Epoch 8/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0142 - mae: 0.0857 - val_loss: 0.0075 - val_mae: 0.0628
# Epoch 9/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0135 - mae: 0.0826 - val_loss: 0.0078 - val_mae: 0.0636
# Epoch 10/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0122 - mae: 0.0764 - val_loss: 0.0079 - val_mae: 0.0651
# Epoch 11/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0122 - mae: 0.0759 - val_loss: 0.0068 - val_mae: 0.0597
# Epoch 12/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0114 - mae: 0.0738 - val_loss: 0.0063 - val_mae: 0.0570
# Epoch 13/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0103 - mae: 0.0693 - val_loss: 0.0058 - val_mae: 0.0555
# Epoch 14/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0108 - mae: 0.0700 - val_loss: 0.0084 - val_mae: 0.0660
# Epoch 15/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0106 - mae: 0.0690 - val_loss: 0.0058 - val_mae: 0.0558
# Epoch 16/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0100 - mae: 0.0671 - val_loss: 0.0061 - val_mae: 0.0597
# Epoch 17/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0100 - mae: 0.0676 - val_loss: 0.0059 - val_mae: 0.0562
# Epoch 18/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0101 - mae: 0.0664 - val_loss: 0.0096 - val_mae: 0.0738
# Epoch 19/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0099 - mae: 0.0665 - val_loss: 0.0079 - val_mae: 0.0674
# Epoch 20/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0098 - mae: 0.0652 - val_loss: 0.0087 - val_mae: 0.0744
# Epoch 21/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0096 - mae: 0.0643 - val_loss: 0.0092 - val_mae: 0.0733
# Epoch 22/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0100 - mae: 0.0670 - val_loss: 0.0077 - val_mae: 0.0652
# Epoch 23/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0097 - mae: 0.0653 - val_loss: 0.0059 - val_mae: 0.0575
# Epoch 24/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0088 - mae: 0.0617 - val_loss: 0.0054 - val_mae: 0.0539
# Epoch 25/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0090 - mae: 0.0627 - val_loss: 0.0085 - val_mae: 0.0699
# Epoch 26/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0087 - mae: 0.0602 - val_loss: 0.0071 - val_mae: 0.0650
# Epoch 27/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0089 - mae: 0.0621 - val_loss: 0.0105 - val_mae: 0.0794
# Epoch 28/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0089 - mae: 0.0619 - val_loss: 0.0077 - val_mae: 0.0670
# Epoch 29/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0085 - mae: 0.0601 - val_loss: 0.0057 - val_mae: 0.0565
# Epoch 30/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0086 - mae: 0.0607 - val_loss: 0.0099 - val_mae: 0.0794
# Epoch 31/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0089 - mae: 0.0623 - val_loss: 0.0050 - val_mae: 0.0543
# Epoch 32/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0084 - mae: 0.0598 - val_loss: 0.0088 - val_mae: 0.0724
# Epoch 33/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0089 - mae: 0.0602 - val_loss: 0.0087 - val_mae: 0.0708
# Epoch 34/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0089 - mae: 0.0607 - val_loss: 0.0068 - val_mae: 0.0613
# Epoch 35/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0084 - mae: 0.0599 - val_loss: 0.0092 - val_mae: 0.0706
# Epoch 36/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0084 - mae: 0.0591 - val_loss: 0.0051 - val_mae: 0.0522
# Epoch 37/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0087 - mae: 0.0606 - val_loss: 0.0063 - val_mae: 0.0601
# Epoch 38/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0082 - mae: 0.0586 - val_loss: 0.0070 - val_mae: 0.0625
# Epoch 39/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0083 - mae: 0.0584 - val_loss: 0.0051 - val_mae: 0.0546
# Epoch 40/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0084 - mae: 0.0591 - val_loss: 0.0080 - val_mae: 0.0657
# Epoch 41/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0082 - mae: 0.0584 - val_loss: 0.0074 - val_mae: 0.0655
# Epoch 42/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0082 - mae: 0.0572 - val_loss: 0.0074 - val_mae: 0.0664
# Epoch 43/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0573 - val_loss: 0.0092 - val_mae: 0.0713
# Epoch 44/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0080 - mae: 0.0564 - val_loss: 0.0058 - val_mae: 0.0569
# Epoch 45/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0080 - mae: 0.0561 - val_loss: 0.0063 - val_mae: 0.0602
# Epoch 46/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0570 - val_loss: 0.0061 - val_mae: 0.0596
# Epoch 47/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0578 - val_loss: 0.0076 - val_mae: 0.0665
# Epoch 48/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0559 - val_loss: 0.0075 - val_mae: 0.0680
# Epoch 49/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0080 - mae: 0.0563 - val_loss: 0.0062 - val_mae: 0.0593
# Epoch 50/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0569 - val_loss: 0.0032 - val_mae: 0.0417
# Epoch 51/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0086 - mae: 0.0584 - val_loss: 0.0085 - val_mae: 0.0699
# Epoch 52/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0082 - mae: 0.0574 - val_loss: 0.0052 - val_mae: 0.0542
# Epoch 53/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0565 - val_loss: 0.0061 - val_mae: 0.0589
# Epoch 54/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0077 - mae: 0.0544 - val_loss: 0.0078 - val_mae: 0.0667
# Epoch 55/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0554 - val_loss: 0.0088 - val_mae: 0.0716
# Epoch 56/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0083 - mae: 0.0573 - val_loss: 0.0048 - val_mae: 0.0518
# Epoch 57/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0077 - mae: 0.0557 - val_loss: 0.0038 - val_mae: 0.0443
# Epoch 58/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0578 - val_loss: 0.0051 - val_mae: 0.0522
# Epoch 59/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0556 - val_loss: 0.0039 - val_mae: 0.0450
# Epoch 60/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0575 - val_loss: 0.0051 - val_mae: 0.0507
# Epoch 61/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0077 - mae: 0.0552 - val_loss: 0.0059 - val_mae: 0.0578
# Epoch 62/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0080 - mae: 0.0562 - val_loss: 0.0078 - val_mae: 0.0684
# Epoch 63/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0557 - val_loss: 0.0059 - val_mae: 0.0577
# Epoch 64/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0083 - mae: 0.0583 - val_loss: 0.0071 - val_mae: 0.0642
# Epoch 65/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0076 - mae: 0.0545 - val_loss: 0.0057 - val_mae: 0.0563
# Epoch 66/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0079 - mae: 0.0550 - val_loss: 0.0057 - val_mae: 0.0565
# Epoch 67/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0559 - val_loss: 0.0080 - val_mae: 0.0675
# Epoch 68/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0076 - mae: 0.0547 - val_loss: 0.0044 - val_mae: 0.0478
# Epoch 69/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0541 - val_loss: 0.0037 - val_mae: 0.0436
# Epoch 70/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0566 - val_loss: 0.0063 - val_mae: 0.0606
# Epoch 71/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0073 - mae: 0.0536 - val_loss: 0.0051 - val_mae: 0.0544
# Epoch 72/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0076 - mae: 0.0556 - val_loss: 0.0070 - val_mae: 0.0606
# Epoch 73/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0074 - mae: 0.0542 - val_loss: 0.0062 - val_mae: 0.0597
# Epoch 74/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0548 - val_loss: 0.0052 - val_mae: 0.0538
# Epoch 75/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0074 - mae: 0.0528 - val_loss: 0.0064 - val_mae: 0.0598
# Epoch 76/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0073 - mae: 0.0528 - val_loss: 0.0068 - val_mae: 0.0632
# Epoch 77/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0533 - val_loss: 0.0046 - val_mae: 0.0505
# Epoch 78/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0073 - mae: 0.0521 - val_loss: 0.0044 - val_mae: 0.0494
# Epoch 79/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0534 - val_loss: 0.0059 - val_mae: 0.0579
# Epoch 80/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0551 - val_loss: 0.0045 - val_mae: 0.0498
# Epoch 81/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0531 - val_loss: 0.0043 - val_mae: 0.0478
# Epoch 82/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0554 - val_loss: 0.0046 - val_mae: 0.0507
# Epoch 83/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0081 - mae: 0.0579 - val_loss: 0.0068 - val_mae: 0.0625
# Epoch 84/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0557 - val_loss: 0.0090 - val_mae: 0.0725
# Epoch 85/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0076 - mae: 0.0543 - val_loss: 0.0084 - val_mae: 0.0704
# Epoch 86/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0525 - val_loss: 0.0052 - val_mae: 0.0520
# Epoch 87/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0076 - mae: 0.0539 - val_loss: 0.0071 - val_mae: 0.0638
# Epoch 88/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0550 - val_loss: 0.0038 - val_mae: 0.0445
# Epoch 89/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0074 - mae: 0.0524 - val_loss: 0.0049 - val_mae: 0.0530
# Epoch 90/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0072 - mae: 0.0520 - val_loss: 0.0046 - val_mae: 0.0502
# Epoch 91/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0077 - mae: 0.0542 - val_loss: 0.0061 - val_mae: 0.0569
# Epoch 92/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0078 - mae: 0.0549 - val_loss: 0.0035 - val_mae: 0.0416
# Epoch 93/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0076 - mae: 0.0539 - val_loss: 0.0050 - val_mae: 0.0530
# Epoch 94/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0074 - mae: 0.0535 - val_loss: 0.0055 - val_mae: 0.0527
# Epoch 95/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0071 - mae: 0.0521 - val_loss: 0.0048 - val_mae: 0.0520
# Epoch 96/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0531 - val_loss: 0.0066 - val_mae: 0.0611
# Epoch 97/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0073 - mae: 0.0531 - val_loss: 0.0072 - val_mae: 0.0652
# Epoch 98/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0075 - mae: 0.0534 - val_loss: 0.0054 - val_mae: 0.0557
# Epoch 99/100
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0072 - mae: 0.0526 - val_loss: 0.0057 - val_mae: 0.0538
# Epoch 100/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0071 - mae: 0.0524 - val_loss: 0.0056 - val_mae: 0.0558
# 12/12 [==============================] - 0s 526us/step

# %% [markdown]
# 驗證方法

# %%
#補epoch 對應的loss 的圖

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# 1.計算均方誤差 (MSE)衡量預測值與真實值的偏差平方的平均值，越小越好
mse = mean_squared_error(y_val_rescaled, y_pred_rescaled)
print(f"Mean Squared Error (MSE): {mse:.2f}")
# 計算平均絕對誤差 (MAE)衡量預測值與真實值的絕對誤差的平均值，越小越好
mae = mean_absolute_error(y_val_rescaled, y_pred_rescaled)
print(f"Mean Absolute Error (MAE): {mae:.2f}")

# 2.計算 R²
r2 = r2_score(y_val_rescaled, y_pred_rescaled)
print(f"R² Score: {r2:.2f}")#越接近 1，表示模型的擬合效果越好。

# 3.計算準確率（誤差在10%以內）統計準確率
tolerance = 0.3  # 誤差範圍
correct_predictions = np.sum(np.abs(y_val_rescaled - y_pred_rescaled) <= (tolerance * y_val_rescaled))
accuracy = correct_predictions / len(y_val_rescaled) * 100
print(f"Accuracy within 10% tolerance: {accuracy:.2f}%")
#4.繪製殘差圖
# 計算殘差
residuals = y_val_rescaled - y_pred_rescaled

# 繪製殘差圖(越接近0平均分佈越好)
plt.figure(figsize=(15, 6))
plt.scatter(range(len(residuals)), residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('Samples')
plt.ylabel('Residuals (Actual - Predicted)')
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error (MSE): 209.73
# Mean Absolute Error (MAE): 11.08
# R² Score: 0.89
# Accuracy within 10% tolerance: 70.28%

# %%
# 繪製 epoch 對應 loss 的圖
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='x')
plt.title('Epoch vs Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
